# %% [markdown]
# ## El problema

# %% [markdown]
# Los bancos en busca de mejorar la vida de las personas ofrecen productos financieros que en ocasiones resultan riesgosos para la propia entidad, como lo son los creditos. Saber si un cliente será buen pagador o incurrirá en mora es un problema del día a día, ya que tener un cliente en mora le puede costar mucho dinero al banco. Es allí donde con ayuda del analisis de datos y modelos de machine learning, se ha logrado detectar cuáles son las variables que ayudan a detectar un buen cliente y uno que no, logrando captar al menos el 65% de los clientes que pueden incurrir en mora.

# %% [markdown]
# ## Los datos

# %% [markdown]
# Para este proyecto se ha utilizado la data de HomeCredit. Tenemos información de más de 300K solicitudes de crédito que incluyen datos sobre el género, nivel de ingresos, nivel educativo, nivel de endeudamiento, antigüedad laboral, entre otras.

# %% [markdown]
# ## Hallazgos clave

# %%
from IPython.display import Image

Image('../Reports/figures/01_target_distribution.png')

# %% [markdown]
# En esta gráfica podemos observar la distribución entre clientes que pagan y los que incurren en impago, siendo los primeros de los que más datos se tienen. Con más de 300K solicitudes analizadas, el 8% -aproximadamente 24.000 clientes- representan un riesgo directo de pérdida para el banco, haciendo crítica la detección temprana de estos perfiles.

# %%
Image('../Reports/figures/06_tasa_impago_rango_edad.png')

# %% [markdown]
# En esta gráfica podemos observar los diferentes rangos de edad y qué tanto incurren en impago por cada rango. Hay una clara relación entre la edad y la tasa de impago, siendo las personas más jovenes los que más incurren en esto con un 12% comparado con menos de 6% para las personas de mayor edad. Para el banco representa un perfil de mayor riesgo cuanto más joven es el cliente.

# %%
Image('../Reports/figures/03_impago_por_tipo_ingreso.png')

# %% [markdown]
# Aquí se puede ver la relación entre el tipo de ingreso y la tasa de impago. El grupo con mayor tasa de impago -40% aprox.- son las personas con baja por maternidad, seguido de los desempleados con un 35%, mientras que los estudiantes y los dueños de negocio tienen un nivel de impago de aproximadamente 0%. Con estos datos es recomendable requerir garantías adicionales o avalistas, así como la posibilidad de una tasa de interés mayor por el alto riesgo.

# %% [markdown]
# ## El Modelo y sus Resultados

# %% [markdown]
# El modelo que se ha entrenado para este proyecto busca identificar las variables de mayor peso a la hora de detectar los clientes que incurren en impago, logrando detectar hasta el 65% de estos perfiles. El modelo encontró que las 5 variables que más importan a la hora de detectar los perfiles de impago son: las fuentes externas de scoring crediticio -de las cuales tenemos 3-, cuánto cubre el crédito del valor del bien a financiar y el género del cliente*.
#
# *Si bien el género aparece como variable relevante, su uso en decisiones crediticias debe evaluarse bajo el marco regulatorio vigente.

# %% [markdown]
# ## Conclusiones y Recomendaciones

# %% [markdown]
# El uso del modelo empleado ayuda a automatizar la tarea de detección de perfiles de riesgo con una fiabilidad del 75%, reduciendo los costes operativos y tiempos para el banco. Se debe evaluar su impacto en el negocio y posibles mejoras antes de su implementación.
#
# Si bien el análisis realizado en este proyecto se pudo detectar el 65% de los impagos, existen limitaciones con respecto a la data, tales como la antigüedad de los datos, la ubicación geográfica y posibles relaciones no detectadas durante la exploración.
#
# Se debe evaluar la posibilidad de obtener nuevos datos para tener un perfil actualizado de los clientes que ayuden al modelo a detectar impagos con datos que reflejen la realidad actual.
# Es recomendable probar otros modelos, así como realizar una limpieza más profunda sobre las variables relevantes para el modelo con el fin de mejorar el rendimiento del mismo.
